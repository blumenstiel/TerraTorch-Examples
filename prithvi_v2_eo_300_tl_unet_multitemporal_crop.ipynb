# %% [markdown]
# # Setup
# 1. Install TerraTorch

# %%
# !pip install terratorch==0.99.8 gdown tensorboard
# Out:
# Requirement already satisfied: terratorch==0.99.8 in ./venv/lib/python3.11/site-packages (0.99.8)
# Requirement already satisfied: gdown in ./venv/lib/python3.11/site-packages (5.2.0)
# Requirement already satisfied: tensorboard in ./venv/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: torch==2.6.0 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (2.6.0)
# Requirement already satisfied: torchvision==0.21.0 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.21.0)
# Requirement already satisfied: rioxarray==0.18.2 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.18.2)
# Requirement already satisfied: albumentations==1.4.10 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.4.10)
# Requirement already satisfied: albucore==0.0.16 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.0.16)
# Requirement already satisfied: rasterio==1.4.3 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.4.3)
# Requirement already satisfied: torchmetrics==1.6.1 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.6.1)
# Requirement already satisfied: geopandas==1.0.1 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.0.1)
# Requirement already satisfied: lightly==1.5.18 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.5.18)
# Requirement already satisfied: jsonargparse==4.35.0 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (4.35.0)
# Requirement already satisfied: h5py==3.12.1 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (3.12.1)
# Requirement already satisfied: mlflow==2.20.1 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (2.20.1)
# Requirement already satisfied: lightning==2.5.0.post0 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (2.5.0.post0)
# Requirement already satisfied: segmentation-models-pytorch in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.4.0)
# Requirement already satisfied: pytest==8.3.4 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (8.3.4)
# Requirement already satisfied: torchgeo==0.6.2 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.6.2)
# Requirement already satisfied: einops==0.8.0 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.8.0)
# Requirement already satisfied: numpy>=1.24 in ./venv/lib/python3.11/site-packages (from albucore==0.0.16->terratorch==0.99.8) (1.26.4)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in ./venv/lib/python3.11/site-packages (from albucore==0.0.16->terratorch==0.99.8) (4.11.0.86)
# Requirement already satisfied: scipy>=1.10.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (1.15.1)
# Requirement already satisfied: scikit-image>=0.21.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (0.25.1)
# Requirement already satisfied: PyYAML in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (4.12.2)
# Requirement already satisfied: scikit-learn>=1.3.2 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (1.6.1)
# Requirement already satisfied: pydantic>=2.7.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (2.10.6)
# Requirement already satisfied: pyogrio>=0.7.2 in ./venv/lib/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.8) (0.10.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.8) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in ./venv/lib/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.8) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in ./venv/lib/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.8) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in ./venv/lib/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.8) (2.0.7)
# Requirement already satisfied: certifi>=14.05.14 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (2025.1.31)
# Requirement already satisfied: hydra-core>=1.0.0 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (1.3.2)
# Requirement already satisfied: lightly_utils~=0.0.0 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (0.0.2)
# Requirement already satisfied: python_dateutil>=2.5.3 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (2.9.0.post0)
# Requirement already satisfied: requests>=2.23.0 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (2.32.3)
# Requirement already satisfied: six>=1.10 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (1.17.0)
# Requirement already satisfied: tqdm>=4.44 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (4.67.1)
# Requirement already satisfied: pytorch_lightning>=1.0.4 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (2.5.0.post0)
# Requirement already satisfied: urllib3>=1.25.3 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (2.3.0)
# Requirement already satisfied: aenum>=3.1.11 in ./venv/lib/python3.11/site-packages (from lightly==1.5.18->terratorch==0.99.8) (3.1.15)
# Requirement already satisfied: fsspec[http]<2026.0,>=2022.5.0 in ./venv/lib/python3.11/site-packages (from lightning==2.5.0.post0->terratorch==0.99.8) (2025.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in ./venv/lib/python3.11/site-packages (from lightning==2.5.0.post0->terratorch==0.99.8) (0.12.0)
# Requirement already satisfied: mlflow-skinny==2.20.1 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (2.20.1)
# Requirement already satisfied: Flask<4 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (3.1.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (1.14.1)
# Requirement already satisfied: docker<8,>=4.0.0 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (7.1.0)
# Requirement already satisfied: graphene<4 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (3.4.3)
# Requirement already satisfied: gunicorn<24 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (3.7)
# Requirement already satisfied: matplotlib<4 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (3.10.0)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (18.1.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./venv/lib/python3.11/site-packages (from mlflow==2.20.1->terratorch==0.99.8) (2.0.38)
# Requirement already satisfied: iniconfig in ./venv/lib/python3.11/site-packages (from pytest==8.3.4->terratorch==0.99.8) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./venv/lib/python3.11/site-packages (from pytest==8.3.4->terratorch==0.99.8) (1.5.0)
# Requirement already satisfied: affine in ./venv/lib/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.8) (2.4.0)
# Requirement already satisfied: attrs in ./venv/lib/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.8) (25.1.0)
# Requirement already satisfied: click>=4.0 in ./venv/lib/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.8) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in ./venv/lib/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.8) (0.7.2)
# Requirement already satisfied: click-plugins in ./venv/lib/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.8) (1.1.1)
# Requirement already satisfied: pyparsing in ./venv/lib/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.8) (3.2.1)
# Requirement already satisfied: xarray>=2024.7.0 in ./venv/lib/python3.11/site-packages (from rioxarray==0.18.2->terratorch==0.99.8) (2025.1.2)
# Requirement already satisfied: filelock in ./venv/lib/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.8) (3.17.0)
# Requirement already satisfied: networkx in ./venv/lib/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.8) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in ./venv/lib/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.8) (1.13.1)
# Requirement already satisfied: fiona>=1.8.21 in ./venv/lib/python3.11/site-packages (from torchgeo==0.6.2->terratorch==0.99.8) (1.10.1)
# Requirement already satisfied: kornia>=0.7.3 in ./venv/lib/python3.11/site-packages (from torchgeo==0.6.2->terratorch==0.99.8) (0.8.0)
# Requirement already satisfied: pillow>=8.4 in ./venv/lib/python3.11/site-packages (from torchgeo==0.6.2->terratorch==0.99.8) (11.1.0)
# Requirement already satisfied: rtree>=1 in ./venv/lib/python3.11/site-packages (from torchgeo==0.6.2->terratorch==0.99.8) (1.3.0)
# Requirement already satisfied: timm>=0.4.12 in ./venv/lib/python3.11/site-packages (from torchgeo==0.6.2->terratorch==0.99.8) (1.0.14)
# Requirement already satisfied: cachetools<6,>=5.0.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (5.5.1)
# Requirement already satisfied: cloudpickle<4 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (0.43.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (1.30.0)
# Requirement already satisfied: protobuf<6,>=3.12.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (5.29.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (0.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.11/site-packages (from sympy==1.13.1->torch==2.6.0->terratorch==0.99.8) (1.3.0)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.11/site-packages (from gdown) (4.13.3)
# Requirement already satisfied: absl-py>=0.4 in ./venv/lib/python3.11/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in ./venv/lib/python3.11/site-packages (from tensorboard) (1.70.0)
# Requirement already satisfied: setuptools>=41.0.0 in ./venv/lib/python3.11/site-packages (from tensorboard) (68.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./venv/lib/python3.11/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./venv/lib/python3.11/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: efficientnet-pytorch>=0.6.1 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (0.7.1)
# Requirement already satisfied: huggingface-hub>=0.24 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (0.28.1)
# Requirement already satisfied: pretrainedmodels>=0.7.1 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (0.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests>=2.23.0->lightly==1.5.18->terratorch==0.99.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests>=2.23.0->lightly==1.5.18->terratorch==0.99.8) (3.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./venv/lib/python3.11/site-packages (from requests>=2.23.0->lightly==1.5.18->terratorch==0.99.8) (1.7.1)
# Requirement already satisfied: Mako in ./venv/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.20.1->terratorch==0.99.8) (1.3.9)
# Requirement already satisfied: itsdangerous>=2.2 in ./venv/lib/python3.11/site-packages (from Flask<4->mlflow==2.20.1->terratorch==0.99.8) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in ./venv/lib/python3.11/site-packages (from Flask<4->mlflow==2.20.1->terratorch==0.99.8) (1.9.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./venv/lib/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.8) (3.11.12)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in ./venv/lib/python3.11/site-packages (from graphene<4->mlflow==2.20.1->terratorch==0.99.8) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in ./venv/lib/python3.11/site-packages (from graphene<4->mlflow==2.20.1->terratorch==0.99.8) (3.2.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in ./venv/lib/python3.11/site-packages (from hydra-core>=1.0.0->lightly==1.5.18->terratorch==0.99.8) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./venv/lib/python3.11/site-packages (from hydra-core>=1.0.0->lightly==1.5.18->terratorch==0.99.8) (4.9.3)
# Requirement already satisfied: kornia_rs>=0.1.0 in ./venv/lib/python3.11/site-packages (from kornia>=0.7.3->torchgeo==0.6.2->terratorch==0.99.8) (0.1.8)
# Requirement already satisfied: rich<14.0,>=12.3.0 in ./venv/lib/python3.11/site-packages (from lightning==2.5.0.post0->terratorch==0.99.8) (13.9.4)
# Requirement already satisfied: tensorboardX<3.0,>=2.2 in ./venv/lib/python3.11/site-packages (from lightning==2.5.0.post0->terratorch==0.99.8) (2.6.2.2)
# Requirement already satisfied: bitsandbytes<1.0,>=0.42.0 in ./venv/lib/python3.11/site-packages (from lightning==2.5.0.post0->terratorch==0.99.8) (0.42.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.20.1->terratorch==0.99.8) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.20.1->terratorch==0.99.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.20.1->terratorch==0.99.8) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.20.1->terratorch==0.99.8) (1.4.8)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas==1.0.1->terratorch==0.99.8) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas==1.0.1->terratorch==0.99.8) (2025.1)
# Requirement already satisfied: munch in ./venv/lib/python3.11/site-packages (from pretrainedmodels>=0.7.1->segmentation-models-pytorch->terratorch==0.99.8) (4.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.10->terratorch==0.99.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./venv/lib/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.10->terratorch==0.99.8) (2.27.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->terratorch==0.99.8) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->terratorch==0.99.8) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->terratorch==0.99.8) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.11/site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->terratorch==0.99.8) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.11/site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->terratorch==0.99.8) (3.5.0)
# Requirement already satisfied: safetensors in ./venv/lib/python3.11/site-packages (from timm>=0.4.12->torchgeo==0.6.2->terratorch==0.99.8) (0.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.8) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.8) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.8) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.8) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.8) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.8) (1.18.3)
# Requirement already satisfied: google-auth~=2.0 in ./venv/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./venv/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (3.21.0)
# Requirement already satisfied: docstring-parser>=0.15 in ./venv/lib/python3.11/site-packages (from jsonargparse==4.35.0->terratorch==0.99.8) (0.16)
# Requirement already satisfied: typeshed-client>=2.1.0 in ./venv/lib/python3.11/site-packages (from jsonargparse==4.35.0->terratorch==0.99.8) (2.7.0)
# Requirement already satisfied: deprecated>=1.2.6 in ./venv/lib/python3.11/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in ./venv/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (0.51b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning==2.5.0.post0->terratorch==0.99.8) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning==2.5.0.post0->terratorch==0.99.8) (2.19.1)
# Requirement already satisfied: wrapt<2,>=1.10 in ./venv/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (4.9)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.3.0->lightning==2.5.0.post0->terratorch==0.99.8) (0.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in ./venv/lib/python3.11/site-packages (from typeshed-client>=2.1.0->jsonargparse==4.35.0->terratorch==0.99.8) (6.5.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow==2.20.1->terratorch==0.99.8) (0.6.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Collecting git+https://github.com/IBM/terratorch.git
#   Cloning https://github.com/IBM/terratorch.git to /private/var/folders/sr/4k1bv9r565d12nx315mt59_r0000gp/T/pip-req-build-9sadaj1r
#   Running command git clone --filter=blob:none --quiet https://github.com/IBM/terratorch.git /private/var/folders/sr/4k1bv9r565d12nx315mt59_r0000gp/T/pip-req-build-9sadaj1r
#   Resolved https://github.com/IBM/terratorch.git to commit 3c3d59defebe62ba202a345a27b45055eb88ea61
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (2.6.0)
# Requirement already satisfied: torchvision in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.21.0)
# Requirement already satisfied: rioxarray in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.18.2)
# Requirement already satisfied: albumentations==1.4.10 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.4.10)
# Requirement already satisfied: albucore==0.0.16 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.0.16)
# Requirement already satisfied: rasterio in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.4.3)
# Requirement already satisfied: torchmetrics in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.6.1)
# Requirement already satisfied: geopandas in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.0.1)
# Requirement already satisfied: lightly in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.5.18)
# Requirement already satisfied: jsonargparse<=4.35.0 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (4.35.0)
# Requirement already satisfied: h5py in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (3.12.1)
# Requirement already satisfied: mlflow in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (2.20.1)
# Requirement already satisfied: lightning in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (2.5.0.post0)
# Requirement already satisfied: segmentation-models-pytorch in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.4.0)
# Requirement already satisfied: pytest in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (8.3.4)
# Requirement already satisfied: torchgeo in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.6.2)
# Requirement already satisfied: einops in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.8.0)
# Requirement already satisfied: numpy>=1.24 in ./venv/lib/python3.11/site-packages (from albucore==0.0.16->terratorch==0.99.8) (1.26.4)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in ./venv/lib/python3.11/site-packages (from albucore==0.0.16->terratorch==0.99.8) (4.11.0.86)
# Requirement already satisfied: scipy>=1.10.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (1.15.1)
# Requirement already satisfied: scikit-image>=0.21.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (0.25.1)
# Requirement already satisfied: PyYAML in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (4.12.2)
# Requirement already satisfied: scikit-learn>=1.3.2 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (1.6.1)
# Requirement already satisfied: pydantic>=2.7.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (2.10.6)
# Requirement already satisfied: pyogrio>=0.7.2 in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (0.10.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (2.0.7)
# Requirement already satisfied: certifi>=14.05.14 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2025.1.31)
# Requirement already satisfied: hydra-core>=1.0.0 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (1.3.2)
# Requirement already satisfied: lightly_utils~=0.0.0 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (0.0.2)
# Requirement already satisfied: python_dateutil>=2.5.3 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2.9.0.post0)
# Requirement already satisfied: requests>=2.23.0 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2.32.3)
# Requirement already satisfied: six>=1.10 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (1.17.0)
# Requirement already satisfied: tqdm>=4.44 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (4.67.1)
# Requirement already satisfied: pytorch_lightning>=1.0.4 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2.5.0.post0)
# Requirement already satisfied: urllib3>=1.25.3 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2.3.0)
# Requirement already satisfied: aenum>=3.1.11 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (3.1.15)
# Requirement already satisfied: fsspec[http]<2026.0,>=2022.5.0 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (2025.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (0.12.0)
# Requirement already satisfied: filelock in ./venv/lib/python3.11/site-packages (from torch->terratorch==0.99.8) (3.17.0)
# Requirement already satisfied: networkx in ./venv/lib/python3.11/site-packages (from torch->terratorch==0.99.8) (3.4.2)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.11/site-packages (from torch->terratorch==0.99.8) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in ./venv/lib/python3.11/site-packages (from torch->terratorch==0.99.8) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.11/site-packages (from sympy==1.13.1->torch->terratorch==0.99.8) (1.3.0)
# Requirement already satisfied: mlflow-skinny==2.20.1 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (2.20.1)
# Requirement already satisfied: Flask<4 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (1.14.1)
# Requirement already satisfied: docker<8,>=4.0.0 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (7.1.0)
# Requirement already satisfied: graphene<4 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (3.4.3)
# Requirement already satisfied: gunicorn<24 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (3.7)
# Requirement already satisfied: matplotlib<4 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (3.10.0)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (18.1.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (2.0.38)
# Requirement already satisfied: cachetools<6,>=5.0.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.43.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (1.30.0)
# Requirement already satisfied: protobuf<6,>=3.12.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (5.29.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.5.3)
# Requirement already satisfied: iniconfig in ./venv/lib/python3.11/site-packages (from pytest->terratorch==0.99.8) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./venv/lib/python3.11/site-packages (from pytest->terratorch==0.99.8) (1.5.0)
# Requirement already satisfied: affine in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (2.4.0)
# Requirement already satisfied: attrs in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (25.1.0)
# Requirement already satisfied: cligj>=0.5 in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (0.7.2)
# Requirement already satisfied: click-plugins in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (1.1.1)
# Requirement already satisfied: pyparsing in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (3.2.1)
# Requirement already satisfied: xarray>=2024.7.0 in ./venv/lib/python3.11/site-packages (from rioxarray->terratorch==0.99.8) (2025.1.2)
# Requirement already satisfied: efficientnet-pytorch>=0.6.1 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (0.7.1)
# Requirement already satisfied: huggingface-hub>=0.24 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (0.28.1)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (11.1.0)
# Requirement already satisfied: pretrainedmodels>=0.7.1 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (0.7.4)
# Requirement already satisfied: timm>=0.9 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (1.0.14)
# Requirement already satisfied: fiona>=1.8.21 in ./venv/lib/python3.11/site-packages (from torchgeo->terratorch==0.99.8) (1.10.1)
# Requirement already satisfied: kornia>=0.7.3 in ./venv/lib/python3.11/site-packages (from torchgeo->terratorch==0.99.8) (0.8.0)
# Requirement already satisfied: rtree>=1 in ./venv/lib/python3.11/site-packages (from torchgeo->terratorch==0.99.8) (1.3.0)
# Requirement already satisfied: Mako in ./venv/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow->terratorch==0.99.8) (1.3.9)
# Requirement already satisfied: Werkzeug>=3.1 in ./venv/lib/python3.11/site-packages (from Flask<4->mlflow->terratorch==0.99.8) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in ./venv/lib/python3.11/site-packages (from Flask<4->mlflow->terratorch==0.99.8) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in ./venv/lib/python3.11/site-packages (from Flask<4->mlflow->terratorch==0.99.8) (1.9.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./venv/lib/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (3.11.12)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in ./venv/lib/python3.11/site-packages (from graphene<4->mlflow->terratorch==0.99.8) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in ./venv/lib/python3.11/site-packages (from graphene<4->mlflow->terratorch==0.99.8) (3.2.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in ./venv/lib/python3.11/site-packages (from hydra-core>=1.0.0->lightly->terratorch==0.99.8) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./venv/lib/python3.11/site-packages (from hydra-core>=1.0.0->lightly->terratorch==0.99.8) (4.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.11/site-packages (from jinja2->torch->terratorch==0.99.8) (3.0.2)
# Requirement already satisfied: kornia_rs>=0.1.0 in ./venv/lib/python3.11/site-packages (from kornia>=0.7.3->torchgeo->terratorch==0.99.8) (0.1.8)
# Requirement already satisfied: setuptools in ./venv/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning->terratorch==0.99.8) (68.2.0)
# Requirement already satisfied: rich<14.0,>=12.3.0 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (13.9.4)
# Requirement already satisfied: tensorboardX<3.0,>=2.2 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (2.6.2.2)
# Requirement already satisfied: bitsandbytes<1.0,>=0.42.0 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (0.42.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow->terratorch==0.99.8) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow->terratorch==0.99.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow->terratorch==0.99.8) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow->terratorch==0.99.8) (1.4.8)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas->terratorch==0.99.8) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas->terratorch==0.99.8) (2025.1)
# Requirement already satisfied: munch in ./venv/lib/python3.11/site-packages (from pretrainedmodels>=0.7.1->segmentation-models-pytorch->terratorch==0.99.8) (4.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.10->terratorch==0.99.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./venv/lib/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.10->terratorch==0.99.8) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests>=2.23.0->lightly->terratorch==0.99.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests>=2.23.0->lightly->terratorch==0.99.8) (3.10)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->terratorch==0.99.8) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->terratorch==0.99.8) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->terratorch==0.99.8) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.11/site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->terratorch==0.99.8) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.11/site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->terratorch==0.99.8) (3.5.0)
# Requirement already satisfied: safetensors in ./venv/lib/python3.11/site-packages (from timm>=0.9->segmentation-models-pytorch->terratorch==0.99.8) (0.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (1.18.3)
# Requirement already satisfied: google-auth~=2.0 in ./venv/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./venv/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (3.21.0)
# Requirement already satisfied: docstring-parser>=0.15 in ./venv/lib/python3.11/site-packages (from jsonargparse<=4.35.0->terratorch==0.99.8) (0.16)
# Requirement already satisfied: typeshed-client>=2.1.0 in ./venv/lib/python3.11/site-packages (from jsonargparse<=4.35.0->terratorch==0.99.8) (2.7.0)
# Requirement already satisfied: deprecated>=1.2.6 in ./venv/lib/python3.11/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in ./venv/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.51b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning->terratorch==0.99.8) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning->terratorch==0.99.8) (2.19.1)
# Requirement already satisfied: wrapt<2,>=1.10 in ./venv/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (4.9)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.3.0->lightning->terratorch==0.99.8) (0.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in ./venv/lib/python3.11/site-packages (from typeshed-client>=2.1.0->jsonargparse<=4.35.0->terratorch==0.99.8) (6.5.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.6.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Fix needed for temporal tasks 
# !pip install git+https://github.com/IBM/terratorch.git
# Out:
# Collecting git+https://github.com/IBM/terratorch.git
#   Cloning https://github.com/IBM/terratorch.git to /private/var/folders/sr/4k1bv9r565d12nx315mt59_r0000gp/T/pip-req-build-9g0v9zy8
#   Running command git clone --filter=blob:none --quiet https://github.com/IBM/terratorch.git /private/var/folders/sr/4k1bv9r565d12nx315mt59_r0000gp/T/pip-req-build-9g0v9zy8
#   Resolved https://github.com/IBM/terratorch.git to commit 3c3d59defebe62ba202a345a27b45055eb88ea61
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (2.6.0)
# Requirement already satisfied: torchvision in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.21.0)
# Requirement already satisfied: rioxarray in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.18.2)
# Requirement already satisfied: albumentations==1.4.10 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.4.10)
# Requirement already satisfied: albucore==0.0.16 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.0.16)
# Requirement already satisfied: rasterio in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.4.3)
# Requirement already satisfied: torchmetrics in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.6.1)
# Requirement already satisfied: geopandas in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.0.1)
# Requirement already satisfied: lightly in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (1.5.18)
# Requirement already satisfied: jsonargparse<=4.35.0 in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (4.35.0)
# Requirement already satisfied: h5py in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (3.12.1)
# Requirement already satisfied: mlflow in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (2.20.1)
# Requirement already satisfied: lightning in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (2.5.0.post0)
# Requirement already satisfied: segmentation-models-pytorch in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.4.0)
# Requirement already satisfied: pytest in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (8.3.4)
# Requirement already satisfied: torchgeo in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.6.2)
# Requirement already satisfied: einops in ./venv/lib/python3.11/site-packages (from terratorch==0.99.8) (0.8.0)
# Requirement already satisfied: numpy>=1.24 in ./venv/lib/python3.11/site-packages (from albucore==0.0.16->terratorch==0.99.8) (1.26.4)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in ./venv/lib/python3.11/site-packages (from albucore==0.0.16->terratorch==0.99.8) (4.11.0.86)
# Requirement already satisfied: scipy>=1.10.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (1.15.1)
# Requirement already satisfied: scikit-image>=0.21.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (0.25.1)
# Requirement already satisfied: PyYAML in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (4.12.2)
# Requirement already satisfied: scikit-learn>=1.3.2 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (1.6.1)
# Requirement already satisfied: pydantic>=2.7.0 in ./venv/lib/python3.11/site-packages (from albumentations==1.4.10->terratorch==0.99.8) (2.10.6)
# Requirement already satisfied: pyogrio>=0.7.2 in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (0.10.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in ./venv/lib/python3.11/site-packages (from geopandas->terratorch==0.99.8) (2.0.7)
# Requirement already satisfied: certifi>=14.05.14 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2025.1.31)
# Requirement already satisfied: hydra-core>=1.0.0 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (1.3.2)
# Requirement already satisfied: lightly_utils~=0.0.0 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (0.0.2)
# Requirement already satisfied: python_dateutil>=2.5.3 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2.9.0.post0)
# Requirement already satisfied: requests>=2.23.0 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2.32.3)
# Requirement already satisfied: six>=1.10 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (1.17.0)
# Requirement already satisfied: tqdm>=4.44 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (4.67.1)
# Requirement already satisfied: pytorch_lightning>=1.0.4 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2.5.0.post0)
# Requirement already satisfied: urllib3>=1.25.3 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (2.3.0)
# Requirement already satisfied: aenum>=3.1.11 in ./venv/lib/python3.11/site-packages (from lightly->terratorch==0.99.8) (3.1.15)
# Requirement already satisfied: fsspec[http]<2026.0,>=2022.5.0 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (2025.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (0.12.0)
# Requirement already satisfied: filelock in ./venv/lib/python3.11/site-packages (from torch->terratorch==0.99.8) (3.17.0)
# Requirement already satisfied: networkx in ./venv/lib/python3.11/site-packages (from torch->terratorch==0.99.8) (3.4.2)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.11/site-packages (from torch->terratorch==0.99.8) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in ./venv/lib/python3.11/site-packages (from torch->terratorch==0.99.8) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.11/site-packages (from sympy==1.13.1->torch->terratorch==0.99.8) (1.3.0)
# Requirement already satisfied: mlflow-skinny==2.20.1 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (2.20.1)
# Requirement already satisfied: Flask<4 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (1.14.1)
# Requirement already satisfied: docker<8,>=4.0.0 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (7.1.0)
# Requirement already satisfied: graphene<4 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (3.4.3)
# Requirement already satisfied: gunicorn<24 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (3.7)
# Requirement already satisfied: matplotlib<4 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (3.10.0)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (18.1.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./venv/lib/python3.11/site-packages (from mlflow->terratorch==0.99.8) (2.0.38)
# Requirement already satisfied: cachetools<6,>=5.0.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.43.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (1.30.0)
# Requirement already satisfied: protobuf<6,>=3.12.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (5.29.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./venv/lib/python3.11/site-packages (from mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.5.3)
# Requirement already satisfied: iniconfig in ./venv/lib/python3.11/site-packages (from pytest->terratorch==0.99.8) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./venv/lib/python3.11/site-packages (from pytest->terratorch==0.99.8) (1.5.0)
# Requirement already satisfied: affine in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (2.4.0)
# Requirement already satisfied: attrs in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (25.1.0)
# Requirement already satisfied: cligj>=0.5 in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (0.7.2)
# Requirement already satisfied: click-plugins in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (1.1.1)
# Requirement already satisfied: pyparsing in ./venv/lib/python3.11/site-packages (from rasterio->terratorch==0.99.8) (3.2.1)
# Requirement already satisfied: xarray>=2024.7.0 in ./venv/lib/python3.11/site-packages (from rioxarray->terratorch==0.99.8) (2025.1.2)
# Requirement already satisfied: efficientnet-pytorch>=0.6.1 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (0.7.1)
# Requirement already satisfied: huggingface-hub>=0.24 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (0.28.1)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (11.1.0)
# Requirement already satisfied: pretrainedmodels>=0.7.1 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (0.7.4)
# Requirement already satisfied: timm>=0.9 in ./venv/lib/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.8) (1.0.14)
# Requirement already satisfied: fiona>=1.8.21 in ./venv/lib/python3.11/site-packages (from torchgeo->terratorch==0.99.8) (1.10.1)
# Requirement already satisfied: kornia>=0.7.3 in ./venv/lib/python3.11/site-packages (from torchgeo->terratorch==0.99.8) (0.8.0)
# Requirement already satisfied: rtree>=1 in ./venv/lib/python3.11/site-packages (from torchgeo->terratorch==0.99.8) (1.3.0)
# Requirement already satisfied: Mako in ./venv/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow->terratorch==0.99.8) (1.3.9)
# Requirement already satisfied: Werkzeug>=3.1 in ./venv/lib/python3.11/site-packages (from Flask<4->mlflow->terratorch==0.99.8) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in ./venv/lib/python3.11/site-packages (from Flask<4->mlflow->terratorch==0.99.8) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in ./venv/lib/python3.11/site-packages (from Flask<4->mlflow->terratorch==0.99.8) (1.9.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./venv/lib/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (3.11.12)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in ./venv/lib/python3.11/site-packages (from graphene<4->mlflow->terratorch==0.99.8) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in ./venv/lib/python3.11/site-packages (from graphene<4->mlflow->terratorch==0.99.8) (3.2.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in ./venv/lib/python3.11/site-packages (from hydra-core>=1.0.0->lightly->terratorch==0.99.8) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./venv/lib/python3.11/site-packages (from hydra-core>=1.0.0->lightly->terratorch==0.99.8) (4.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.11/site-packages (from jinja2->torch->terratorch==0.99.8) (3.0.2)
# Requirement already satisfied: kornia_rs>=0.1.0 in ./venv/lib/python3.11/site-packages (from kornia>=0.7.3->torchgeo->terratorch==0.99.8) (0.1.8)
# Requirement already satisfied: setuptools in ./venv/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning->terratorch==0.99.8) (68.2.0)
# Requirement already satisfied: rich<14.0,>=12.3.0 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (13.9.4)
# Requirement already satisfied: tensorboardX<3.0,>=2.2 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (2.6.2.2)
# Requirement already satisfied: bitsandbytes<1.0,>=0.42.0 in ./venv/lib/python3.11/site-packages (from lightning->terratorch==0.99.8) (0.42.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow->terratorch==0.99.8) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow->terratorch==0.99.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow->terratorch==0.99.8) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.11/site-packages (from matplotlib<4->mlflow->terratorch==0.99.8) (1.4.8)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas->terratorch==0.99.8) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas->terratorch==0.99.8) (2025.1)
# Requirement already satisfied: munch in ./venv/lib/python3.11/site-packages (from pretrainedmodels>=0.7.1->segmentation-models-pytorch->terratorch==0.99.8) (4.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.10->terratorch==0.99.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./venv/lib/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.10->terratorch==0.99.8) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests>=2.23.0->lightly->terratorch==0.99.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests>=2.23.0->lightly->terratorch==0.99.8) (3.10)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->terratorch==0.99.8) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->terratorch==0.99.8) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->terratorch==0.99.8) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.11/site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->terratorch==0.99.8) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.11/site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->terratorch==0.99.8) (3.5.0)
# Requirement already satisfied: safetensors in ./venv/lib/python3.11/site-packages (from timm>=0.9->segmentation-models-pytorch->terratorch==0.99.8) (0.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->terratorch==0.99.8) (1.18.3)
# Requirement already satisfied: google-auth~=2.0 in ./venv/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./venv/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (3.21.0)
# Requirement already satisfied: docstring-parser>=0.15 in ./venv/lib/python3.11/site-packages (from jsonargparse<=4.35.0->terratorch==0.99.8) (0.16)
# Requirement already satisfied: typeshed-client>=2.1.0 in ./venv/lib/python3.11/site-packages (from jsonargparse<=4.35.0->terratorch==0.99.8) (2.7.0)
# Requirement already satisfied: deprecated>=1.2.6 in ./venv/lib/python3.11/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in ./venv/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.51b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning->terratorch==0.99.8) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning->terratorch==0.99.8) (2.19.1)
# Requirement already satisfied: wrapt<2,>=1.10 in ./venv/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (4.9)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.3.0->lightning->terratorch==0.99.8) (0.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in ./venv/lib/python3.11/site-packages (from typeshed-client>=2.1.0->jsonargparse<=4.35.0->terratorch==0.99.8) (6.5.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.1->mlflow->terratorch==0.99.8) (0.6.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import sys
import torch
import gdown
import terratorch
import albumentations
import lightning.pytorch as pl
import matplotlib.pyplot as plt
from terratorch.datamodules import MultiTemporalCropClassificationDataModule

# %% [markdown]
# 2. Download the dataset from Google Drive/HuggingFace

# %%
# Download the full dataset (~24 GB)
if False and not os.path.isfile('multi-temporal-crop-classification.zip'):
    gdown.download("https://drive.google.com/uc?id=1Di_vj2mDuFaHnIUpneHlfOm7mMLekEyk")
    # !unzip multi-temporal-crop-classification.zip    
    # !tar -xvzf datasets--ibm-nasa-geospatial--multi-temporal-crop-classification/snapshots/04b439f179e52a7b144f69676210eecd30c39cfc/training_chips.tgz -C datasets--ibm-nasa-geospatial--multi-temporal-crop-classification/snapshots/04b439f179e52a7b144f69676210eecd30c39cfc/ && tar -xvzf datasets--ibm-nasa-geospatial--multi-temporal-crop-classification/snapshots/04b439f179e52a7b144f69676210eecd30c39cfc/validation_chips.tgz -C datasets--ibm-nasa-geospatial--multi-temporal-crop-classification/snapshots/04b439f179e52a7b144f69676210eecd30c39cfc/ && mv datasets--ibm-nasa-geospatial--multi-temporal-crop-classification/snapshots/04b439f179e52a7b144f69676210eecd30c39cfc/training_data.txt datasets--ibm-nasa-geospatial--multi-temporal-crop-classification/snapshots/04b439f179e52a7b144f69676210eecd30c39cfc/training_chips/ && mv datasets--ibm-nasa-geospatial--multi-temporal-crop-classification/snapshots/04b439f179e52a7b144f69676210eecd30c39cfc/validation_data.txt datasets--ibm-nasa-geospatial--multi-temporal-crop-classification/snapshots/04b439f179e52a7b144f69676210eecd30c39cfc/validation_chips/

dataset_path = 'datasets--ibm-nasa-geospatial--multi-temporal-crop-classification/snapshots/04b439f179e52a7b144f69676210eecd30c39cfc/'

# %%
# Download a random subset for demos (~1 GB)
if not os.path.isfile('multi-temporal-crop-classification-subset.tar.gz'):
    gdown.download("https://drive.google.com/uc?id=1A0cmT-Ye4X4QjETTmsmOh392vaKp7YhB")
    # !tar -xzvf multi-temporal-crop-classification-subset.tar.gz

dataset_path = "multi-temporal-crop-classification-subset"

# %% [markdown]
# ## Multi-temporal Crop Dataset
#
# Lets start with analyzing the dataset

# %%
# !ls "{dataset_path}"

# %%
# Each merged sample includes the stacked bands of three time steps
# !ls "{dataset_path}/training_chips" | head

# %%
# Adjusted dataset class for this dataset (general dataset could be used as well)
datamodule = MultiTemporalCropClassificationDataModule(
    batch_size=16,
    num_workers=4,
    data_root=dataset_path,
    train_transform=[
        terratorch.datasets.transforms.FlattenTemporalIntoChannels(),  # Required for temporal data
        albumentations.D4(), # Random flips and rotation
        albumentations.pytorch.transforms.ToTensorV2(),
        terratorch.datasets.transforms.UnflattenTemporalFromChannels(n_timesteps=3),
    ],
    val_transform=None,  # Using ToTensor() by default
    test_transform=None,
    expand_temporal_dimension=True,
    use_metadata=False, # The crop dataset has metadata for location and time
    reduce_zero_label=True,
)

# Setup train and val datasets
datamodule.setup("fit")

# %%
# checking for the dataset means and stds
datamodule.means, datamodule.stds

# %%
# checking datasets train split size
train_dataset = datamodule.train_dataset
len(train_dataset)

# %%
# checking datasets available bands
train_dataset.all_band_names

# %%
# checking datasets classes
train_dataset.class_names

# %%
# plotting a few samples
for i in range(5):
    train_dataset.plot(train_dataset[i])

# %%
# checking datasets validation split size
val_dataset = datamodule.val_dataset
len(val_dataset)

# %%
# checking datasets testing split size
datamodule.setup("test")
test_dataset = datamodule.test_dataset
len(test_dataset)

# %% [markdown]
# # Fine-tune Prithvi

# %%
pl.seed_everything(0)

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    dirpath="output/multicrop/checkpoints/",
    mode="max",
    monitor="val/Multiclass_Jaccard_Index", # Variable to monitor
    filename="best-epoch-{epoch:02d}",
)

# Lightning Trainer
trainer = pl.Trainer(
    accelerator="auto",
    strategy="auto",
    devices=1, # Lightning multi-gpu often fails in notebooks
    precision='16-mixed',  # Speed up training
    num_nodes=1,
    logger=True, # Uses TensorBoard by default
    max_epochs=2, # For demos
    log_every_n_steps=5,
    enable_checkpointing=True,
    callbacks=[checkpoint_callback, pl.callbacks.RichProgressBar()],
    default_root_dir="output/multicrop",
)

# Model
model = terratorch.tasks.SemanticSegmentationTask(
    model_factory="EncoderDecoderFactory",
    model_args={
        # Backbone
        "backbone": "prithvi_eo_v2_300_tl", # Model can be either prithvi_eo_v1_100, prithvi_eo_v2_300, prithvi_eo_v2_300_tl, prithvi_eo_v2_600, prithvi_eo_v2_600_tl
        "backbone_pretrained": True,
        "backbone_num_frames": 3,
        "backbone_bands": ["BLUE", "GREEN", "RED", "NIR_NARROW", "SWIR_1", "SWIR_2"],
        "backbone_coords_encoding": [], # use ["time", "location"] for time and location metadata
        
        # Necks 
        "necks": [
            {
                "name": "SelectIndices",
                # "indices": [2, 5, 8, 11] # indices for prithvi_eo_v1_100
                "indices": [5, 11, 17, 23] # indices for prithvi_eo_v2_300
                # "indices": [7, 15, 23, 31] # indices for prithvi_eo_v2_600
            },
            {
                "name": "ReshapeTokensToImage",
                "effective_time_dim": 3
            },
            {"name": "LearnedInterpolateToPyramidal"},            
        ],
        
        # Decoder
        "decoder": "UNetDecoder",
        "decoder_channels": [512, 256, 128, 64],
        
        # Head
        "head_dropout": 0.1,
        "num_classes": 13,
    },
    
    loss="ce",
    lr=1e-4,
    optimizer="AdamW",
    ignore_index=-1,
    freeze_backbone=True,  # Speeds up fine-tuning
    freeze_decoder=False,
    plot_on_val=True,
    
)

# %%
# Training
trainer.fit(model, datamodule=datamodule)

# %%
# Open Tensorboard in additional terminal:
# !tensorboard --logdir output # add --host $(hostname -f) for clusters

# %%
best_ckpt_path = "output/multicrop/checkpoints/best-epoch=1.ckpt"

# %%
trainer.test(model, datamodule=datamodule, ckpt_path=best_ckpt_path)

# %%
# now we can use the model for predictions and plotting!
model = terratorch.tasks.SemanticSegmentationTask.load_from_checkpoint(
    best_ckpt_path,
    model_factory=model.hparams.model_factory,
    model_args=model.hparams.model_args,
)

test_loader = datamodule.test_dataloader()
with torch.no_grad():
    batch = next(iter(test_loader))
    images = batch["image"].to(model.device)
    masks = batch["mask"].numpy()

    outputs = model(images)
    preds = torch.argmax(outputs.output, dim=1).cpu().numpy()

for i in range(5):
    sample = {key: batch[key][i] for key in batch}
    sample["prediction"] = preds[i]
    test_dataset.plot(sample)
